# %%
import pandas
import pandas_datareader as pdr
from datetime import datetime

sd = datetime(2021, 4, 1)
ed = datetime(2021, 9, 30)
# vix VIX指數是芝加哥期權交易所市場波動率指數的交易代碼，常見於衡量標準普爾500指數期權的隱含波動性。 通常被稱為「恐慌指數」或「恐慌指標」，它是了解市場對未來30天市場波動性預期的一種衡量方法。
vix = pdr.get_data_yahoo(symbols='^vix', start=sd, end=ed)["Adj Close"]

# %%
data =pdr.get_data_yahoo(symbols=['^vix','2330.TW'], start=sd, end=ed)["Adj Close"]
# 2330 台積電
# Adj Close 收盤價

# %%
data
# Out:
# Symbols        2330.TW       ^vix
# Date
# 2021-04-01  596.796326  17.330000
# 2021-04-05         NaN  17.910000
# 2021-04-06         NaN  18.120001
# 2021-04-07  604.727173  17.160000
# 2021-04-08  607.701294  16.950001
# 2021-04-09  604.727173  16.690001
# 2021-04-12  599.770386  16.910000
# 2021-04-13  599.770386  16.650000
# 2021-04-14  606.709839  16.990000
# 2021-04-15  613.649353  16.570000
# 2021-04-16  604.727173  16.250000
# 2021-04-19  597.787720  17.290001
# 2021-04-20  596.796326  18.680000
# 2021-04-21  586.882751  17.500000
# 2021-04-22  585.891418  18.709999
# 2021-04-23  596.796326  17.330000
# 2021-04-26  604.727173  17.639999
# 2021-04-27  604.727173  17.559999
# 2021-04-28  596.796326  17.280001
# 2021-04-29  594.813660  17.610001
# 2021-04-30         NaN  18.610001
# 2021-05-03  582.917358  18.309999
# 2021-05-04  585.891418  19.480000
# 2021-05-05  579.943237  19.150000
# 2021-05-06  581.925964  18.389999
# 2021-05-07  593.822205  16.690001
# ...

# %%
data_vix = pdr.get_data_yahoo(symbols='^vix', start=sd, end=ed)["Adj Close"]

# %%
data_vix.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
