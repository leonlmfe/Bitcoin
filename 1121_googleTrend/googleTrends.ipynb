# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-US', tz=360) 
kw_list = ['bitcoin']

# %%
# keywords to search for
pytrends.build_payload(kw_list,cat=0, timeframe='today 3-m', geo='', gprop='')

# %%
# dataframe
time_df = pytrends.interest_over_time()
time_df.head()
# Out:
#             bitcoin  isPartial
# date
# 2021-08-25       55      False
# 2021-08-26       52      False
# 2021-08-27       46      False
# 2021-08-28       43      False
# 2021-08-29       42      False

# %%
#1 Interest over Time
data = pytrends.interest_over_time() 
data.head()
data = data.reset_index() 


import plotly.express as px

fig = px.line(time_df, x="date", y=['machine learning'], title='Keyword Web Search Interest Over Time')
fig.show()
# Out:
# <div>                            <div id="4c2cd288-1b79-4c11-b18c-21bb15138c72" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c2cd288-1b79-4c11-b18c-21bb15138c72")) {                    Plotly.newPlot(                        "4c2cd288-1b79-4c11-b18c-21bb15138c72",                        [{"hovertemplate":"variable=machine learning<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"machine learning","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"machine learning","orientation":"v","showlegend":true,"type":"scatter","x":["2021-09-29T00:00:00","2021-09-29T01:00:00","2021-09-29T02:00:00","2021-09-29T03:00:00","2021-09-29T04:00:00","2021-09-29T05:00:00","2021-09-29T06:00:00","2021-09-29T07:00:00","
# ...

# %%
pytrends.get_historical_interest(kw_list, year_start=2021, month_start=10, day_start=1, hour_start=0, year_end=2021, month_end=10, day_end=2, hour_end=0, cat=0, geo='', gprop='', sleep=0)
# Out:
#                      bitcoin  isPartial
# date
# 2021-10-01 00:00:00        0      False
# 2021-10-01 01:00:00        0      False
# 2021-10-01 02:00:00        0      False
# 2021-10-01 03:00:00        0      False
# 2021-10-01 04:00:00        0      False
# 2021-10-01 05:00:00        0      False
# 2021-10-01 06:00:00        0      False
# 2021-10-01 07:00:00        0      False
# 2021-10-01 08:00:00        0      False
# 2021-10-01 09:00:00        0      False
# 2021-10-01 10:00:00        0      False
# 2021-10-01 11:00:00        0      False
# 2021-10-01 12:00:00        0      False
# 2021-10-01 13:00:00        0      False
# 2021-10-01 14:00:00        0      False
# 2021-10-01 15:00:00        0      False
# 2021-10-01 16:00:00        0      False
# 2021-10-01 17:00:00        0      False
# 2021-10-01 18:00:00        0      False
# 2021-10-01 19:00:00        0      False
# 2021-10-01 20:00:00        0      False
# 2021-10-01 21:00:00        0      False
# ...
